# %% [markdown]
# ![logo.png](data:image/png;base64,...)

# %% [markdown]
# #<font color = 'green'>Operaciones y métodos</font>
#
# ##<font color = 'green'>Operaciones con strings</font>

# %%
a = 'Carlos'
b = 'González'
c = '3'
print(a+b)
print(3*a)
print(3*c)
print(b.count('z'))
print(len(b))
print(a.upper())
# Out:
# CarlosGonzález
# CarlosCarlosCarlos
# 333
# 2
# 8
# CARLOS

# %% [markdown]
# ##<font color = 'green'>Operaciones aritméticas</font>

# %%
print(5+3)
print(5-3)
print(5*3)
print(5/3)
print(5//3)
print(5%3)
# Out:
# 8
# 2
# 15
# 1.6666666666666667
# 1
# 2

# %% [markdown]
# ##<font color = 'green'>Operaciones en listas</font>

# %%
lista=[6,2,7,3,9,11,0, 32,-4,1]
print(max(lista))
# Out:
# 32

# %% [markdown]
# Naturalmente, para aplicar este método necesitamos que todos los elementos de la lista sean numéricos,

# %%
lista=[6,2,7,'perro',9,11,0, 32,-4,1]
print(max(lista))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-685858499f9a> in <cell line: 2>()
#       1 lista=[6,2,7,'perro',9,11,0, 32,-4,1]
# ----> 2 print(max(lista))
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# ##<font color = 'green'>Ejercicio - El vendedor</font>
#
# Crearemos ahora un programa que solicita al usuario:
#
# *   El precio de un artículo
# *   La cantidad de ellos que comprará
# *   El porcentaje de descuento que se ofrece para ese artículo
#
# Hecho esto, nos retornará el valor total a pagar, de la forma "El total a pagar es de ... pesos"

# %%
    # Solicitar al usuario el precio del artículo
    precio_articulo = float(input("Ingrese el precio del artículo: "))

    # Solicitar al usuario la cantidad de artículos que comprará
    cantidad_articulos = int(input("Ingrese la cantidad de artículos que comprará: "))

    # Solicitar al usuario el porcentaje de descuento
    porcentaje_descuento = float(input("Ingrese el porcentaje de descuento ofrecido: "))

    # Calcular el total a pagar con el descuento
    descuento = precio_articulo * (porcentaje_descuento / 100)
    total_pagar = (precio_articulo - descuento) * cantidad_articulos

    # Mostrar el resultado
    print(f"El total a pagar es de {total_pagar:.2f} pesos")
# Out:
# Ingrese el precio del artículo: 100
# Ingrese la cantidad de artículos que comprará: 1
# Ingrese el porcentaje de descuento ofrecido: 10
# El total a pagar es de 90.00 pesos

# %% [markdown]
# ##<font color = 'green'>Librerías</font>
#
# Python nos provee de **Librerías,** que son una suerte de "caja de herramientas" con diferentes funciones predefinidas que se pueden importar en un programa para agregar funcionalidades adicionales.

# %%
import random
num_aleatorio = random.randint(1,10)
print(f'El número aleatorio es {num_aleatorio}')
# Out:
# El número aleatorio es 4
